# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Exploration and Cleaning

# %%
# Load a dataset and display the first five rows.
data=pd.read_csv("Demography_of_India.csv")

# %%
data.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
# Display the basic information (column names, data types, etc.) of the dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
# Count the number of missing values in each column.
data.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %%
# Rename the column District_code to District_ID.
data.rename(columns={"District_code":"District_ID"})
# Out:
#      District_ID                   State_name              District_name  \
# 0              1            JAMMU AND KASHMIR                    Kupwara
# 1              2            JAMMU AND KASHMIR                     Badgam
# 2              3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3              4            JAMMU AND KASHMIR                     Kargil
# 4              5            JAMMU AND KASHMIR                      Punch
# ..           ...                          ...                        ...
# 635          636                  PONDICHERRY                       Mahe
# 636          637                  PONDICHERRY                   Karaikal
# 637          638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638          639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639          640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
# Create a new column Total_Population as the sum of Male and Female.
data["Total_Population"]=data["Male"]+data["Female"]
data.head(1)
# Out:
#    District_code         State_name District_name    Male  Female  Literate  \
# 0              1  JAMMU AND KASHMIR       Kupwara  474190  396164    439654
#
#    Workers  Male_Workers  Female_Workers  Cultivator_Workers  ...  Sikhs  \
# 0   229064        190899           38165               34680  ...   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50  \
# 0               21751          600759           178435         89679
#
#    Total_Population
# 0            870354
#
# [1 rows x 25 columns]

# %%
# Convert the State_name column to lowercase.
data["State_name"]=data["State_name"].str.lower()
data.head(1)
# Out:
#    District_code         State_name District_name    Male  Female  Literate  \
# 0              1  jammu and kashmir       Kupwara  474190  396164    439654
#
#    Workers  Male_Workers  Female_Workers  Cultivator_Workers  ...  Sikhs  \
# 0   229064        190899           38165               34680  ...   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50  \
# 0               21751          600759           178435         89679
#
#    Total_Population
# 0            870354
#
# [1 rows x 25 columns]

# %%
# Check for duplicate rows and remove them if found.
data.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# Total_Population        0
# dtype: int64

# %%
# Calculate the total population for each district.
data.groupby("District_name")["Age_Group_0_29"].mean()
# Out:
# District_name
# Adilabad       1536378.0
# Agra           2871903.0
# Ahmadabad      3952858.0
# Ahmadnagar     2496560.0
# Aizawl          235892.0
#                  ...
# Yadgir          738451.0
# Yamunanagar     694813.0
# Yanam            31973.0
# Yavatmal       1549263.0
# Zunheboto        91709.0
# Name: Age_Group_0_29, Length: 634, dtype: float64

# %%
# What is the median value of Male_Workers in the dataset?
data["Male_Workers"].median()
# Out:
# np.float64(428851.5)

# %%
# Calculate the percentage of literate people in each district based on the Population column.
data["percent_of_Literate"]=(data["Literate"]/data["Total_Population"])*100;
data.groupby("District_name")["percent_of_Literate"].sum().round()
# Out:
# District_name
# Adilabad       54.0
# Agra           61.0
# Ahmadabad      75.0
# Ahmadnagar     69.0
# Aizawl         85.0
#                ...
# Yadgir         43.0
# Yamunanagar    69.0
# Yanam          71.0
# Yavatmal       73.0
# Zunheboto      73.0
# Name: percent_of_Literate, Length: 634, dtype: float64

# %%
# Find the district with the highest number of Female_Workers.
data.loc[data["Female_Workers"].idxmax(), "District_name"]
# Out:
# 'Pune'

# %%
# Calculate the standard deviation of Agricultural_Workers across all districts.

# %%
What is the range (difference between the maximum and minimum) of Household_Workers across all districts?
Compute the sum of Hindus, Muslims, Christians, Sikhs, Buddhists, and Jains for each district.
Identify the district with the lowest percentage of Higher_Education.
Find the district with the highest Graduate_Education enrollment.
Data Aggregation
Group the data by State_name and calculate the total Population per state.
Group the data by State_name and calculate the average Male_Workers per state.
Calculate the total number of Workers in each Age_Group_0_29 for all districts.
Find the average number of Cultivator_Workers per state.
Group the data by District_code and find the total Literate population for each district.
Aggregate the dataset by State_name and find the maximum Secondary_Education enrollment in each state.
Group the data by State_name and calculate the total number of Agricultural_Workers.
Calculate the percentage of Workers who are Female_Workers for each district.
Group the dataset by State_name and compute the sum of Male_Workers.
Find the top 5 districts with the highest Household_Workers.
Visualization
Plot the distribution of Secondary_Education across districts.
Create a bar plot to visualize the number of Male_Workers vs. Female_Workers across districts.
Plot a pie chart showing the proportion of different religions (Hindus, Muslims, Christians, Sikhs, Buddhists, Jains) in each district.
Create a scatter plot showing the relationship between Literate and Total_Population.
Plot a heatmap to show correlations between different columns such as Population, Workers, and Age_Group_0_29.
Create a histogram of the Age_Group_30_49 distribution across all districts.
Plot a line chart showing the trend of Graduate_Education over the different districts.
Create a stacked bar chart showing the distribution of Male_Workers, Female_Workers, and Cultivator_Workers in each district.
Create a box plot to show the distribution of Male_Workers in each state.
Plot a bar chart to visualize the total number of Hindus per district.
Advanced Analysis
Perform a correlation analysis between Age_Group_0_29, Age_Group_30_49, and Age_Group_50.
Calculate the ratio of Literate to Population for each district.
Identify the districts with a high percentage of workers in Agricultural_Workers and Household_Workers.
Find the state with the highest total Cultivator_Workers.
Perform a linear regression to predict Male_Workers based on the Population and Literate columns.
Create a new column Worker_Rate as the ratio of Workers to Population and analyze the districts with the highest rates.
Perform a clustering analysis on the dataset based on Population, Workers, and Secondary_Education.
Identify the district with the highest gender disparity in Workers.
Perform a time-series analysis (if you have date-related data) to observe trends in Secondary_Education over time.
Create a function to calculate the Workforce_Population_Ratio (Workers / Population) and analyze its distribution across all districts.
